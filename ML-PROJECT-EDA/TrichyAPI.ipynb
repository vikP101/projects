# %%
import json
import pandas as pd
import requests
from tabulate import tabulate
from sklearn.cluster import KMeans
import random
import numpy as np
import folium
import warnings
warnings.filterwarnings('ignore')
import os
os.environ.keys()

# %%
#Fetching data form HERE API for trichy
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:10.7905,78.7047;r=10000&q=apartment&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
data = requests.get(url).json()
d=pd.json_normalize(data['items'])
d.to_csv('apartment.csv')
d
# Out:
#                                     title  \
# 0                           KBJ Apartment
# 1                       Mangari Apartment
# 2                       Service Apartment
# 3                     Mountzien Apartment
# 4                        Orchid Apartment
# 5       Ark Sangai (Ark Sangai Apartment)
# 6                        Fatima Apartment
# 7  Manghalam Estates (Mangalam Apartment)
# 8                           Ark Apartment
# 9                 Royal (Royal Apartment)
#
#                                                   id language resultType  \
# 0  here:pds:place:356cfbc4-153d688481eed6ae544bc8...       en      place
# 1  here:pds:place:356jx7ps-bc9c608fad210276539ddf...    en-GB      place
# 2  here:pds:place:356t9zvq-1c07f0440e417a73b0b865...       en      place
# 3  here:pds:place:356t9zvq-5bb6deb535552d3a67fa3a...       en      place
# 4  here:pds:place:356jx7ps-eefa75fcdfc30b62c485fc...    en-GB      place
# 5  here:pds:place:356t9zvq-387e0549941cd13acf400f...       en      place
# 6  here:pds:place:356t9zvq-91ac871baee54943b29c6d...    en-GB      place
# 7  here:pds:place:356jx7ps-26efeeb1ed8701e7d8fc38...    en-GB      place
# 8  here:pds:place:356t9zvq-b1d6a6635b0415d7e4191f...       en      place
# 9  here:pds:place:356jx7ps-c1a4db9980b4020f7f48e0...    en-GB      place
#
#                                  access  distance  \
# 0   [{'lat': 10.78904, 'lng': 78.7016}]       374
# 1  [{'lat': 10.78619, 'lng': 78.70171}]       592
# 2  [{'lat': 10.79211, 'lng': 78.69022}]      1591
# 3  [{'lat': 10.78625, 'lng': 78.69881}]       778
# 4  [{'lat': 10.79412, 'lng': 78.69254}]      1378
# 5  [{'lat': 10.79943, 'lng': 78.70367}]       996
# 6  [{'lat': 10.79305, 'lng': 78.69537}]      1058
# 7  [{'lat': 10.80306, 'lng': 78.68525}]      2539
# 8  [{'lat': 10.78292, 'lng': 78.68966}]      1842
# 9  [{'lat': 10.81459, 'lng': 78.70154}]      2711
#
#                                           categories  \
# 0  [{'id': '900-9300-0221', 'name': 'Residential ...
# 1  [{'id': '900-9300-0221', 'name': 'Residential ...
# 2  [{'id': '500-5100-0000', 'name': 'Lodging', 'p...
# 3  [{'id': '900-9300-0221', 'name': 'Residential ...
# 4  [{'id': '900-9300-0221', 'name': 'Residential ...
# 5  [{'id': '900-9300-0221', 'name': 'Residential ...
# 6  [{'id': '900-9300-0221', 'name': 'Residential ...
# 7  [{'id': '900-9300-0221', 'name': 'Residential ...
# 8  [{'id': '900-9300-0221', 'name': 'Residential ...
# 9  [{'id': '900-9300-0221', 'name': 'Residential ...
#
#                                        address.label address.countryCode  \
# 0  KBJ Apartment, 75 Raja Street, Subramanyapur, ...                 IND
# 1  Mangari Apartment, Paneer Selvam Street, Subra...                 IND
# 2  Service Apartment, Kallar Street, Cyclone Labo...                 IND
# 3  Mountzien Apartment, Bharathiyar Street, Subra...                 IND
# 4  Orchid Apartment, Illupur Road, Kallukuzzhi-Ra...                 IND
# 5  Ark Sangai, Sangiliyandapuram Main Road, Sangi...                 IND
# 6  Fatima Apartment, Mudukkupatty Road, Iqbal Col...                 IND
# 7  Manghalam Estates, Cantonment, Tiruchirappalli...                 IND
# 8  Ark Apartment, Quaid E Millath Street, Kaja Na...                 IND
# 9  Royal, Anna Teral Street, Varaganeri Bazar, De...                 IND
#
#   address.countryName  ...   address.county     address.city address.district  \
# 0               India  ...  Tiruchirappalli  Tiruchirappalli    Ponmalaipatti
# 1               India  ...  Tiruchirappalli  Tiruchirappalli    Ponmalaipatti
# 2               India  ...  Tiruchirappalli  Tiruchirappalli       Khajamalai
# 3               India  ...  Tiruchirappalli  Tiruchirappalli    Ponmalaipatti
# 4               India  ...  Tiruchirappalli  Tiruchirappalli       Khajamalai
# 5               India  ...  Tiruchirappalli  Tiruchirappalli        Palakarai
# 6               India  ...  Tiruchirappalli  Tiruchirappalli    Ponmalaipatti
# 7               India  ...  Tiruchirappalli  Tiruchirappalli       Cantonment
# 8               India  ...  Tiruchirappalli  Tiruchirappalli       Khajamalai
# 9               India  ...  Tiruchirappalli  Tiruchirappalli       Devathanam
#
#               address.subdistrict               address.street  \
# 0                   Subramanyapur                  Raja Street
# 1                   Subramanyapur         Paneer Selvam Street
# 2  Cyclone Labour Colony Quarters                Kallar Street
# 3                   Subramanyapur           Bharathiyar Street
# 4   Kallukuzzhi-Ramakrishna Nagar                 Illupur Road
# 5               Sangiliyandapuram  Sangiliyandapuram Main Road
# 6                    Iqbal Colony            Mudukkupatty Road
# 7                             NaN                          NaN
# 8            Kaja Nagar Slum Area       Quaid E Millath Street
# 9                Varaganeri Bazar            Anna Teral Street
#
#   address.postalCode address.houseNumber position.lat position.lng  \
# 0             620020                  75     10.78907     78.70160
# 1             620020                 NaN     10.78617     78.70155
# 2             620020                 NaN     10.79214     78.69023
# 3             620020                 NaN     10.78630     78.69900
# 4             620020                 NaN     10.79421     78.69266
# 5             620008                 NaN     10.79938     78.70354
# 6             620020                 NaN     10.79305     78.69537
# 7             620001                 NaN     10.80315     78.68535
# 8             620020                 NaN     10.78298     78.68967
# 9             620002                 NaN     10.81466     78.70140
#
#                                           references
# 0                                                NaN
# 1  [{'supplier': {'id': 'core'}, 'id': '111065084...
# 2                                                NaN
# 3                                                NaN
# 4  [{'supplier': {'id': 'core'}, 'id': '111034617...
# 5                                                NaN
# 6  [{'supplier': {'id': 'core'}, 'id': '111059019...
# 7  [{'supplier': {'id': 'core'}, 'id': '111224340...
# 8                                                NaN
# 9  [{'supplier': {'id': 'core'}, 'id': '111224904...
#
# [10 rows x 22 columns]

# %%
#Cleaning API data
d2=d[['title','address.label','distance','access','position.lat','position.lng','address.postalCode','id']]
d2.to_csv('cleaned_apartment.csv')
d2
# Out:
#                                     title  \
# 0                           KBJ Apartment
# 1                       Mangari Apartment
# 2                       Service Apartment
# 3                     Mountzien Apartment
# 4                        Orchid Apartment
# 5       Ark Sangai (Ark Sangai Apartment)
# 6                        Fatima Apartment
# 7  Manghalam Estates (Mangalam Apartment)
# 8                           Ark Apartment
# 9                 Royal (Royal Apartment)
#
#                                        address.label  distance  \
# 0  KBJ Apartment, 75 Raja Street, Subramanyapur, ...       374
# 1  Mangari Apartment, Paneer Selvam Street, Subra...       592
# 2  Service Apartment, Kallar Street, Cyclone Labo...      1591
# 3  Mountzien Apartment, Bharathiyar Street, Subra...       778
# 4  Orchid Apartment, Illupur Road, Kallukuzzhi-Ra...      1378
# 5  Ark Sangai, Sangiliyandapuram Main Road, Sangi...       996
# 6  Fatima Apartment, Mudukkupatty Road, Iqbal Col...      1058
# 7  Manghalam Estates, Cantonment, Tiruchirappalli...      2539
# 8  Ark Apartment, Quaid E Millath Street, Kaja Na...      1842
# 9  Royal, Anna Teral Street, Varaganeri Bazar, De...      2711
#
#                                  access  position.lat  position.lng  \
# 0   [{'lat': 10.78904, 'lng': 78.7016}]      10.78907      78.70160
# 1  [{'lat': 10.78619, 'lng': 78.70171}]      10.78617      78.70155
# 2  [{'lat': 10.79211, 'lng': 78.69022}]      10.79214      78.69023
# 3  [{'lat': 10.78625, 'lng': 78.69881}]      10.78630      78.69900
# 4  [{'lat': 10.79412, 'lng': 78.69254}]      10.79421      78.69266
# 5  [{'lat': 10.79943, 'lng': 78.70367}]      10.79938      78.70354
# 6  [{'lat': 10.79305, 'lng': 78.69537}]      10.79305      78.69537
# 7  [{'lat': 10.80306, 'lng': 78.68525}]      10.80315      78.68535
# 8  [{'lat': 10.78292, 'lng': 78.68966}]      10.78298      78.68967
# 9  [{'lat': 10.81459, 'lng': 78.70154}]      10.81466      78.70140
#
#   address.postalCode                                                 id
# 0             620020  here:pds:place:356cfbc4-153d688481eed6ae544bc8...
# 1             620020  here:pds:place:356jx7ps-bc9c608fad210276539ddf...
# 2             620020  here:pds:place:356t9zvq-1c07f0440e417a73b0b865...
# 3             620020  here:pds:place:356t9zvq-5bb6deb535552d3a67fa3a...
# 4             620020  here:pds:place:356jx7ps-eefa75fcdfc30b62c485fc...
# 5             620008  here:pds:place:356t9zvq-387e0549941cd13acf400f...
# 6             620020  here:pds:place:356t9zvq-91ac871baee54943b29c6d...
# 7             620001  here:pds:place:356jx7ps-26efeeb1ed8701e7d8fc38...
# 8             620020  here:pds:place:356t9zvq-b1d6a6635b0415d7e4191f...
# 9             620002  here:pds:place:356jx7ps-c1a4db9980b4020f7f48e0...

# %%
#Counting no. of cafes, department stores and gyms near apartments around Trichy
df_final=d2[['position.lat','position.lng']]

CafeList=[]
ResList=[]
GymList=[]
latitudes = list(d2['position.lat'])
longitudes = list( d2['position.lng'])
for lat, lng in zip(latitudes, longitudes):
    radius = '1000' #Set the radius to 1000 metres
    latitude=lat
    longitude=lng

    search_query = 'cafe' #Search for any cafes
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=pd.json_normalize(results['items'])
    CafeList.append(len(venues))

    search_query = 'gym' #Search for any gyms
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=pd.json_normalize(results['items'])
    GymList.append(len(venues))

    search_query = 'restaurents' #search for supermarkets
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=pd.json_normalize(results['items'])
    ResList.append(len(venues))

df_final['Cafes'] = CafeList
df_final['Restaurents'] = ResList
df_final['Gyms'] = GymList
df_final
# Out:
#    position.lat  position.lng  Cafes  Restaurents  Gyms
# 0      10.78907      78.70160      4           20     1
# 1      10.78617      78.70155      4           20     1
# 2      10.79214      78.69023     11           20     1
# 3      10.78630      78.69900      5           20     1
# 4      10.79421      78.69266      9           20     1
# 5      10.79938      78.70354      3           17     0
# 6      10.79305      78.69537      4           20     1
# 7      10.80315      78.68535     11           20     2
# 8      10.78298      78.68967      3           20     1
# 9      10.81466      78.70140      6           20     1

# %%
#Run K-means clustering on dataframe
kclusters = 3

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_final)
df_final['Cluster']=kmeans.labels_
df_final['Cluster']=df_final['Cluster'].apply(str)
df_final
# Out:
#    position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 0      10.78907      78.70160      4           20     1       2
# 1      10.78617      78.70155      4           20     1       2
# 2      10.79214      78.69023     11           20     1       1
# 3      10.78630      78.69900      5           20     1       2
# 4      10.79421      78.69266      9           20     1       1
# 5      10.79938      78.70354      3           17     0       0
# 6      10.79305      78.69537      4           20     1       2
# 7      10.80315      78.68535     11           20     2       1
# 8      10.78298      78.68967      3           20     1       2
# 9      10.81466      78.70140      6           20     1       2

# %%
#Plotting clustered locations on map using Folium

#define coordinates of the college
map_bom=folium.Map(location=[10.7905,78.7047],zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='0':
        return 'green'
    elif cluster=='1':
        return 'orange'
    else:
        return 'red'

latitudes = list(df_final['position.lat'])
longitudes = list(df_final['position.lng'])
labels = list(df_final['Cluster'])
names=list(d2['title'])
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=5,
            color=color_producer(label)
        ).add_to(map_bom)

# add locations to map
map_bom.add_child(locations)
folium.Marker([10.7905,78.7047],popup='Trichy').add_to(map_bom)

# %%
#saving the map
map_bom.save("map-Trichy.html")
